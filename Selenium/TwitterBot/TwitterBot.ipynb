# %%
from selenium import webdriver

from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC

from webdriver_manager.chrome import ChromeDriverManager
from time import sleep
import pandas as pd

# %%
servico = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=servico)
driver.get("https://twitter.com/login") 
sleep(3)

# %%
nomeUsuario = driver.find_element(By.XPATH,"//input[@name='text']")
nomeUsuario.send_keys("YOUR EMAIL ADDRESS HERE")
avancar = driver.find_element(By.XPATH, value='//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div/div/div/div[6]/div')
avancar.click()
sleep(3)

# %%
telefone = driver.find_element(By.XPATH, value='//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[2]/label/div/div[2]/div/input')
telefone.send_keys('YOUR PHONE NUMBER HERE')
buttonPhone = driver.find_element(By.XPATH, value='//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div/div/div')
buttonPhone.click()
sleep(3)

# %%
senha = driver.find_element(By.XPATH,"//input[@name='password']")
senha.send_keys('YOUR PASSWORD HERE')
loginButton = driver.find_element(By.XPATH, '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div')
loginButton.click()
sleep(5)

# %%
subject = '@jairbolsonaro' # HASHTAG
search_box = driver.find_element(by=By.XPATH, value="/html/body/div[1]/div/div/div[2]/main/div/div/div/div[2]/div/div[2]/div/div/div/div[1]/div/div/div/form/div[1]/div/div/div/label/div[2]/div/input")
search_box.send_keys(subject)
search_box.send_keys(Keys.ENTER)

# %%
articles = driver.find_elements(By.XPATH,"//article[@data-testid='tweet']")

# %%
UserTags = []
TimeStamps = []
Tweets = []
Replys = []
reTweets = []
Likes = []

# %%
for article in articles:
    
        UserTag = driver.find_element(By.XPATH,".//div[@data-testid='User-Names']").text
        UserTags.append(UserTag)
        
        TimeStamp = driver.find_element(By.XPATH,".//time").get_attribute('datetime')
        TimeStamps.append(TimeStamp)
        
        Tweet = driver.find_element(By.XPATH,".//div[@data-testid='tweetText']").text
        Tweets.append(Tweet)
        
        Reply = driver.find_element(By.XPATH,".//div[@data-testid='reply']").text
        Replys.append(Reply)
        
        reTweet = driver.find_element(By.XPATH,".//div[@data-testid='retweet']").text
        reTweets.append(reTweet)
        
        Like = driver.find_element(By.XPATH,".//div[@data-testid='like']").text
        Likes.append(Like)

        driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
        sleep(3)
        articles = driver.find_elements(By.XPATH,"//article[@data-testid='tweet']")
        
        Tweets2 = list(set(Tweets))
        
        if len(Tweets2) > 100:
            break

# %%
data = {
    'Tag de usuário': UserTags,
    'TimeStamp': TimeStamps,
    'Tweet': Tweets,
    'Replys': Replys,
    'ReTweets': reTweets,
    'Likes': Likes
}

# %%
df = pd.DataFrame(data)
display(df)
# Out:
#                                        Tag de usuário  \
# 0                Jorge Serrão\n@alertatotal\n·\nMar 6
# 1                 Débora Franco\n@Debbimf73\n·\nMar 6
# 2                David Ágape\n@david_agape_\n·\nMar 5
# 3                          ƁσƖѕσIcє\n@IceSohei\n·\n7h
# 4                Danilo Balas\n@DaniloBalas\n·\nMar 6
# 5              Helena NENA\n@NenaHelenaLima\n·\nMar 6
# 6                  𝐀𝐑𝐀𝐂𝐈 𝐁𝐑𝐎𝐋𝐎\n@AraciBrolo\n·\nMar 6
# 7        Marcia Carapinha\n@CarapinhaMarcia\n·\nMar 7
# 8       Patriarca del Fructus\n@vzla_apesta\n·\nMar 5
# 9             Joca Oliver\n@JocaOliverSou40\n·\nMar 5
# 10                     ariana\n@MarianaOlly\n·\nMar 5
# 11                      desfaked\n@desfaked\n·\nMar 7
# 12        Adriana Schmitz\n@AdrianaSchmit20\n·\nMar 5
# 13          Sarah Leah Whitson\n@sarahleah1\n·\nMar 5
# 14                Minho Hussein\n@HusseinMinho\n·\n2h
# 15                               @JosianaZs\n·\nMar 5
# 16                            CleanMyMac\n@cleanmymac
# 17                       NTD News\n@NTDNews\n·\nMar 5
# 18                            CleanMyMac\n@cleanmymac
# 19  maristela mella marinho\n@marinho_mella\n·\nMar 5
# 20              Marcelo Gomes\n@marcelogn73\n·\nMar 6
# 21             Léo Maranhão\n@LeoMaranhao22\n·\nMar 6
# 22                           K\n@KAFearless\n·\nMar 5
# 23  Tocador de tambor na praia.\n@Paulomarinho2\n·...
# 24  Carla Ruthes Coelho - against the ivory tower\...
# 25                            neptune.ai\n@neptune_ai
# 26      Claudio Xavante Casaldáliga\n@xavvante\n·\n2h
# 27      Claudio Xavante Casaldáliga\n@xavvante\n·\n2h
# 28      Claudio Xavante Casaldáliga\n@xavvante\n·\n2h
# 29      Claudio Xavante Casaldáliga\n@xavvante\n·\n2h
# 30      Claudio Xavante Casaldáliga\n@xavvante\n·\n2h
#
#                    TimeStamp  \
# 0   2023-03-06T16:03:56.000Z
# 1   2023-03-06T16:33:52.000Z
# 2   2023-03-05T19:40:55.000Z
# 3   2023-03-08T10:48:02.000Z
# 4   2023-03-06T23:03:16.000Z
# 5   2023-03-06T11:05:22.000Z
# 6   2023-03-06T21:53:23.000Z
# 7   2023-03-07T12:08:13.000Z
# 8   2023-03-05T16:09:32.000Z
# 9   2023-03-05T14:37:03.000Z
# 10  2023-03-05T17:24:39.000Z
# 11  2023-03-07T11:45:42.000Z
# 12  2023-03-05T14:24:11.000Z
# 13  2023-03-05T22:45:41.000Z
# 14  2023-03-08T16:11:10.000Z
# 15  2023-03-05T14:44:03.000Z
# 16  2023-03-05T19:13:01.000Z
# 17  2023-03-05T22:35:01.000Z
# 18  2023-03-07T16:50:48.000Z
# 19  2023-03-05T12:31:30.000Z
# 20  2023-03-06T22:39:29.000Z
# 21  2023-03-06T15:46:02.000Z
# 22  2023-03-05T09:10:11.000Z
# 23  2023-03-07T22:45:44.000Z
# 24  2023-03-08T18:59:49.000Z
# 25  2023-03-08T16:53:37.000Z
# 26  2023-03-08T16:53:37.000Z
# 27  2023-03-08T16:53:37.000Z
# 28  2023-03-08T16:53:37.000Z
# 29  2023-03-08T16:53:37.000Z
# 30  2023-03-08T16:53:37.000Z
#
#                                                 Tweet Replys ReTweets  Likes
# 0   Você gosta do \n@jairbolsonaro\n ??? A petralh...    254    1,940  8,531
# 1                              Volta \n@jairbolsonaro      3       13     68
# 2   Na reta final das eleições de 2022 o TSE arqui...      7      228    918
# 3   O Legado que Ficou marcado.\nMais avanços conc...               6     15
# 4   O Governador \n@tarcisiogdf\n sempre busca a m...      3       20     91
# 5   World !? Any good souls!? #elonmusk #trump #ri...              18     30
# 6   Minha singela homenagem ao melhor Presidente d...      6       19     62
# 7   Essa CARNIÇA \n@jairbolsonaro\n não pode ficar...      5       19    288
# 8   Aprovecho la fecha para recordar el mejor disc...      5      116    240
# 9                                 Jair baba e Misheik               6     15
# 10   Um fenômeno chamado Bolsonaro\n\nO melhor pre...      5       12     89
# 11             HAHAHAH O medo de ser preso, meu Deus!      2       11    113
# 12  @jairbolsonaro\n volta já pra casa, não  estou...      2        6     27
# 13  Cuz it’s actually quite easy for MBS to spread...      6        2      8
# 14  #BolsonaroNaCadeia\n Não é de hoje, que Bostan...               1      7
# 15  Como o Sr pode \n@jairbolsonaro\nE ter esse gr...      1       12     16
# 16       Is your Mac ready for the new macOS Ventura?     70      105    504
# 17  .\n@jairbolsonaro\n, the 38th President of #Br...      1        2      6
# 18      How to tell if your MacBook has memory issues     10       35     81
# 19  https://twitter.com/Fabianoazev/status/1632128...                      1
# 20  Esse é meu Presidente \n@jairbolsonaro\n ! Sem...      1       15     35
# 21  Excelente!! Saudades meu presidente, não assis...      4        5    113
# 22  Yes he’s loved so much he ran from his country...      2        4     26
# 23                                        E as jóias?               1      5
# 24  It’s international women’s day. I want to remi...
# 25  Machine Learning Experiment tracking and Model...    699      906  2,727
# 26  Ontem o Bananinha deu xilique na Câmara e cham...               2      4
# 27  Ontem o Bananinha deu xilique na Câmara e cham...               2      4
# 28  Ontem o Bananinha deu xilique na Câmara e cham...               2      4
# 29  Ontem o Bananinha deu xilique na Câmara e cham...               2      4
# 30  Ontem o Bananinha deu xilique na Câmara e cham...               2      4

# %%
df.to_excel('jairbolsonaro.xlsx', index = False)
